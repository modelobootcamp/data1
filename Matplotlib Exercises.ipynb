# %% [markdown]
# ___
#
# <a href='https://bootcamp.extension.ucsd.edu/wp-content/uploads/sites/92/2018/01/ucsd-building-548x300.jpg'> <img src='https://bootcamp.extension.ucsd.edu/wp-content/uploads/sites/92/2018/01/ucsd-building-548x300.jpg' /></a>
# ___
# # Matplotlib Exercises
#
# Welcome to the exercises for reviewing matplotlib! Take your time with these, Matplotlib can be tricky to understand at first. These are relatively simple plots, but they can be hard if this is your first time with matplotlib, feel free to reference the solutions as you go along.
#
# Also don't worry if you find the matplotlib syntax frustrating, we actually won't be using it that often throughout the course, we will switch to using seaborn and pandas built-in visualization capabilities. But, those are built-off of matplotlib, which is why it is still important to get exposure to it!
#
# ** * NOTE: ALL THE COMMANDS FOR PLOTTING A FIGURE SHOULD ALL GO IN THE SAME CELL. SEPARATING THEM OUT INTO MULTIPLE CELLS MAY CAUSE NOTHING TO SHOW UP. * **
#
# # Exercises
#
# Follow the instructions to recreate the plots using this data:
#
# ## Data

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
from matplotlib.pyplot import *
#import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# ** Import matplotlib.pyplot as plt and set %matplotlib inline if you are using the jupyter notebook. What command do you use if you aren't using the jupyter notebook?**

# %%
plt.plot(x,y)

# %%
import numpy as np
x = np.linspace(0,5,11)
y = x **2

# %%
plt.plot(x,y)

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y, 'r-')

# %%
plt.plot(x,y)
plt.xlabel('x label')
plt.ylabel('ylabel')
plt.title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %%
plt.subplot(1,2,1)
plt.plot(x,y, 'r')
plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %%
#01
fig = plt.figure()

# %%
#02
fig = plt.figure()
axes = fig.add_axes()

# %%
#03
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.8])

# %%
#04
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)

# %%
#05
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)
axes.set_xlabel('xLable')
axes.set_ylabel('yLable')
axes.set_title('Set Title')
# Out:
# Text(0.5, 1.0, 'Set Title')

# %%
#06
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

#axes = fig.add_axes([0.1,0.1,0.8,0.8])
#axes.plot(x,y)
#axes.set_xlabel('xLable')
#axes.set_ylabel('yLable')
#axes.set_title('Set Title')

# %%
#07
fig = plt.figure()

#axes = fig.add_axes([Left,Bottom,weight,Height])
axes1 = fig.add_axes([0.3,0.1,0.3,0.1])
axes2 = fig.add_axes([0.2,0.3,0.4,0.2])
axes3 = fig.add_axes([0.4,0.2,0.5,0.7])


#axes = fig.add_axes([0.1,0.1,0.8,0.8])
#axes.plot(x,y)
#axes.set_xlabel('xLable')
#axes.set_ylabel('yLable')
#axes.set_title('Set Title')

# %%
#08
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x,y)
axes1.set_title('Larger Plot')

axes2.plot(y,x)
axes2.set_title('Smaller Plot')
# Out:
# Text(0.5, 1.0, 'Smaller Plot')

# %%
fig,axes = plt.subplots()

# %%
fig,axes = plt.subplots()
axes.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)

# %%
fig,axes = plt.subplots(nrows=3,ncols=3)

# %%
fig,axes = plt.subplots(nrows=3,ncols=3)
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)

# %%
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000019C36063FD0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000019C360B2048>],
#       dtype=object)

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)
for current_ax in axes:
    current_ax.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)
axes[0].plot(x,y)
axes[1].plot(x,y)

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)


axes[0].plot(x,y)
axes[0].set_title('First Plot')

axes[1].plot(x,y)
axes[1].set_title('Second Plot')
# Out:
# Text(0.5, 1.0, 'Second Plot')

# %%
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000019C3626BD30>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000019C36291128>],
#       dtype=object)

# %%
fig = plt.figure(figsize=(8,2))

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig, axes = plt.subplots(figsize=(8,2))

axes.plot(x,y)

# %%
fig.axes = plt.subplots(nrows=2,ncols=1,figsize=(8,2))


axes[0].plot(x,y)
axes[1].plot(y,x)
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-f8cd9a376f2d> in <module>
# ----> 1 fig.axes = plt.subplots(nrows=2,ncols=1,figsize=(8,2))
#       2
#       3
#       4 axes[0].plot(x,y)
#       5 axes[1].plot(y,x)
#
# AttributeError: can't set attribute

# %%
fig,axes = plt.subplots(nrows=2, ncols=1,figsize=(8,2))

# %%
fig.savefig('my_picture.PNG')

# %%
fig.savefig('my_picture.jpg')

# %%
fig.savefig('my_picture.pdf')

# %%
fig.savefig('my_picture.PNG',dpi=600)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y)
ax.set_title('Title')
ax.set_ylabel('yLabel')
plt.tight_layout()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py:2366: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
fig=plt.figure(figsize=(3,2),dpi=100)

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig=plt.figure(figsize=(3,2),dpi=100)

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=2,ncols=1,figsize=(3,2))

axes.plot(x,y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-d06e87d3feca> in <module>
#       1 fig,axes = plt.subplots(nrows=2,ncols=1,figsize=(3,2))
#       2
# ----> 3 axes.plot(x,y)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
fig,axes = plt.subplots(nrows=2,ncols=1,figsize=(8,6))

axes[0].plot(x,y)
axes[1].plot(y,x)

# %%
fig.savefig('my_picture.png')

# %%
fig.savefig('my_picture.png',dpi=200)

# %%
fig,axes = plt.subplots(nrows=2,ncols=1,figsize=(8,6))

axes[0].plot(x,y)
axes[1].plot(y,x)

# %%
fig=plt.figure(figsize=(3,2),dpi=100)

ax,plot(x,y)
ax.plot(y,x)

# %%
fig=plt.figure()


ax = fig.add_axes([0,0,1,1])
ax,plot(x,x**2)
ax.plot(x,x**3)

# %%
fig=plt.figure()


ax = fig.add_axes([0,0,1,1])
ax,plot(x,x**2,label='x Squared')
ax.plot(x,x**3, label='x Cubed')

ax.legend()

# %%
fig=plt.figure()


ax = fig.add_axes([0,0,1,1])
ax,plot(x,x**2,label='x Squared')
ax.plot(x,x**3, label='x Cubed')

ax.legend(loc=1)
# https://matplotlib.org/api/legend_api.html

# %%
fig=plt.figure()


ax = fig.add_axes([0,0,1,1])
ax,plot(x,x**2,label='x Squared')
ax.plot(x,x**3, label='x Cubed')

ax.legend(loc=10)
# https://matplotlib.org/api/legend_api.html

# %%
fig=plt.figure()


ax = fig.add_axes([0,0,1,1])
ax,plot(x,x**2,label='x Squared')
ax.plot(x,x**3, label='x Cubed')

ax.legend(loc=3)
# https://matplotlib.org/api/legend_api.html

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='purple')

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='purple',linewidth=2)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='purple',linewidth=20)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='purple',linewidth=3,alpha=0.5) #transparency

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='purple',lw=3,alpha=0.5) #transparency

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='purple',lw=3,linestyle='-.')

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='purple',lw=3,linestyle=':')

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='purple',lw=3,linestyle='steps')

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='purple',lw=3,ls='steps')

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='purple',lw=3,ls='-',marker='o')

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='purple',lw=0.1,ls='-',marker='+')

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='purple',lw=1,ls='-',marker='o',markersize=20)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='purple',lw=1,ls='-',marker='o',markersize=20,
markerfacecolor='yellow',markeredgewidth=3,markeredgecolor='green')

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, x+1, color="red", linewidth=0.25)
ax.plot(x, x+2, color="red", linewidth=0.50)
ax.plot(x, x+3, color="red", linewidth=1.00)
ax.plot(x, x+4, color="red", linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(x, x+5, color="green", lw=3, linestyle='-')
ax.plot(x, x+6, color="green", lw=3, ls='-.')
ax.plot(x, x+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(x, x+8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(x, x+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(x, x+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(x, x+12, color="blue", lw=3, ls='--', marker='1')

# marker size and color
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='purple',lw=3,linestyle='--')
ax.set_xlim([0,1])
ax.set_ylim([0,2])
# Out:
# (0, 2)

# %% [markdown]
# ## Exercise 1
#
# ** Follow along with these steps: **
# * ** Create a figure object called fig using plt.figure() **
# * ** Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax. **
# * ** Plot (x,y) on that axes and set the labels and titles to match the plot below:**

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %% [markdown]
# ## Exercise 2
# ** Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ** Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
fig = plt.figure()

ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,.5,.2,.2])

ax1.plot(x,y,color='red')
ax2.plot(x,y)

# %% [markdown]
# ## Exercise 3
#
# ** Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]**

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([.2,.5,.4,.4])

# %% [markdown]
# ** Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:**

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([.2,.5,.4,.4])

# Large
ax.plot(x,y)
ax.set_xlabel('x')
ax.set_ylabel('z')

# Insert
ax2.plot(x,y)
ax2.set_title('zoom')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.set_xlim([20,22])
ax2.set_ylim([30,50])
# Out:
# (30, 50)

# %% [markdown]
# ## Exercise 4
#
# ** Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %%
fig,axes = plt.subplots(1,2)

# %% [markdown]
# ** Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %%
fig,axes = plt.subplots(1,2)
axes[0].plot(x,y,color='blue',lw=3,ls='--')
axes[1].plot(x,z,color='red',lw=3)

# %% [markdown]
# ** See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.**

# %%
fig,axes = plt.subplots(1,2,figsize=(12,2))
axes[0].plot(x,y,color='blue',lw=3,ls='--')
axes[1].plot(x,z,color='red',lw=3,ls='--')

# %% [markdown]
# # Finished
